# %% [markdown]
# <font size="20"><ins>**Course Recommender System**</ins></font>
#
# <font size="5">July 28th 2024</font>

# %% [markdown]
# # 1. Introduction

# %% [markdown]
# ===============================================================================================================================================================================
#
# **Background**:
#
# New students hard to find the suitable course based on their preference and knowledge level
#
# **Objectives**:
#
# Developing system recommendation to provide the suitable course based on student’s preference
#
# **Dataset Overview**
#
# Dataset yang digunakan merupakan ...
#
#
# | Nama Kolom | Tipe Data | Deskripsi |
# | --- | --- | --- |
# |...|...  | ... |
# |... 	| ... 	| ... |
# |...	| ...	| ... |
# | ...	|  ...|... |
# |...  |	...	| ... |
# | ...	|...|  ...|
# |  ...|...		| ... |
#
# ===============================================================================================================================================================================

# %% [markdown]
# # 2. Import Libraries

# %%
## Import libraries
from selenium import webdriver
import bs4
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# # 3. Data Loading

# %%
# Import Raw Dataset
df_raw = pd.read_csv('webautomation_coursera.csv')

# Display First 5 rows from Dataset
df_raw.head()
# Out:
#                                                  url  \
# 0  https://www.coursera.org/specializations/netwo...
# 1          https://www.coursera.org/learn/2-speed-it
# 2  https://www.coursera.org/learn/fundamentals-ne...
# 3      https://www.coursera.org/learn/ux-design-jobs
# 4  https://www.coursera.org/learn/database-applic...
#
#                                                title  \
# 0          Networking in Google Cloud Specialization
# 1  Two Speed IT: How Companies Can Surf the Digit...
# 2              Fundamentals of Network Communication
# 3  Design a User Experience for Social Good & Pre...
# 4              Building Database Applications in PHP
#
#   associated-university-institution-company             type  \
# 0                              Google Cloud  specializations
# 1                           CentraleSupélec           course
# 2             University of Colorado System           course
# 3                                    Google           course
# 4                    University of Michigan           course
#
#                                                image  \
# 0  https://s3.amazonaws.com/coursera_assets/meta_...
# 1  https://s3.amazonaws.com/coursera_assets/meta_...
# 2  https://s3.amazonaws.com/coursera_assets/meta_...
# 3  https://s3.amazonaws.com/coursera_assets/meta_...
# 4  https://s3.amazonaws.com/coursera_assets/meta_...
#
#             category-subject-area certificate-is-available  \
# 0                      Networking    Shareable Certificate
# 1             Business Essentials    Shareable Certificate
# 2  Computer Security and Networks    Shareable Certificate
# 3              Design and Product    Shareable Certificate
# 4      Mobile and Web Development    Shareable Certificate
#
#                                          description  \
# 0  This specialization gives participants broad s...
# 1  Transform or disappear, the Darwinism of IT: I...
# 2  In this course, we trace the evolution of netw...
# 3  Design a User Experience for Social Good and P...
# 4  In this course, we'll look at the object orien...
#
#                              duration language               level  \
# 0  Approximately 4 months to complete  English  Intermediate Level
# 1        Approx. 14 hours to complete  English                   -
# 2        Approx. 15 hours to complete  English  Intermediate Level
# 3        Approx. 71 hours to complete  English      Beginner Level
# 4        Approx. 24 hours to complete  English  Intermediate Level
#
#   prerequisites price rating  \
# 0             -  free    4.8
# 1             -  free    4.3
# 2             -  free    4.6
# 3             -  free    4.8
# 4             -  free    4.9
#
#                                             syllabus             timestamp
# 0                                                  -  2022-07-29T23:58:34Z
# 1  Introduction ~.~ Start here! ~.~ IT and the CI...  2022-07-29T23:58:34Z
# 2  Communication Networks and Services ~.~ This m...  2022-07-29T23:58:54Z
# 3  Starting the UX design process: empathize, def...  2022-07-29T23:59:20Z
# 4  PHP Objects ~.~ We look at the object oriented...  2022-07-29T23:59:20Z

# %%
df_raw.info()# Menampilkan summary dari data df dengan menggunakan .info()
print('Informasi data: ', '\n')
print(df_raw.info())
print('Data yang kosong: ', df_raw.isnull().sum().sum()) # Check apakah ada data null
print('Data yang duplicate: ', df_raw.duplicated().sum()) # Check apakah ada data null
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 16 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   url                                        242 non-null    object
#  1   title                                      242 non-null    object
#  2   associated-university-institution-company  242 non-null    object
#  3   type                                       242 non-null    object
#  4   image                                      242 non-null    object
#  5   category-subject-area                      242 non-null    object
#  6   certificate-is-available                   242 non-null    object
#  7   description                                242 non-null    object
#  8   duration                                   242 non-null    object
#  9   language                                   242 non-null    object
#  10  level                                      242 non-null    object
#  11  prerequisites                              242 non-null    object
#  12  price                                      242 non-null    object
#  13  rating                                     242 non-null    object
#  14  syllabus                                   242 non-null    object
#  15  timestamp                                  242 non-null    object
# dtypes: object(16)
# memory usage: 30.4+ KB
# Informasi data:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 16 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   url                                        242 non-null    object
#  1   title                                      242 non-null    object
#  2   associated-university-institution-company  242 non-null    object
#  3   type                                       242 non-null    object
#  4   image                                      242 non-null    object
#  5   category-subject-area                      242 non-null    object
#  6   certificate-is-available                   242 non-null    object
#  7   description                                242 non-null    object
#  8   duration                                   242 non-null    object
#  9   language                                   242 non-null    object
#  10  level                                      242 non-null    object
#  11  prerequisites                              242 non-null    object
#  12  price                                      242 non-null    object
#  13  rating                                     242 non-null    object
#  14  syllabus                                   242 non-null    object
#  15  timestamp                                  242 non-null    object
# dtypes: object(16)
# memory usage: 30.4+ KB
# None
# Data yang kosong:  0
# Data yang duplicate:  5

# %%
# Drop Duplicated rows from dataset
df_raw.drop_duplicates(inplace=True)

# Re-check the duplicated
df_raw.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Insight**
# - ...

# %% [markdown]
# # 4. Web Scripping

# %%
# create driver
driver = webdriver.Chrome()
# Out:
# The chromedriver version (125.0.6422.78) detected in PATH at c:\Users\andre\Hactiv8\Phase 2\Final Project\chromedriver.exe might not be compatible with the detected chrome version (126.0.6478.185); currently, chromedriver 126.0.6478.182 is recommended for chrome 126.*, so it is advised to delete the driver in PATH and retry

# %%
# Buat list unutk menampung nilai
list_titles = []
list_modules = []
list_instructors_name = []

# sediakan url
url = df_raw['url'][0]

# akses website
driver.get(url)

# extract html
html = driver.page_source

# Parsing html
soup = BeautifulSoup(html, 'html.parser') 

# 1. Mengambil title course
title = soup.find('h1')
list_titles.append(title.get_text())
list_titles = ','.join(list_titles)

# 2. Mengambil nama module
modules = soup.find_all('h3', {'class':'cds-119'})
for module in modules:
    list_modules.append(module.get_text())

# Join semua data menjadi 1 baris
list_modules = ','.join(list_modules)

# Mengambil nama instruktur
instructor_name = soup.find_all('div', {'class':'css-1f454bp'})
for name in instructor_name:
    list_instructors_name.append(name.get_text())

# Join semua data menjadi 1 baris
list_instructors_name = ','.join(list_instructors_name)

# Gabungkan di dataframe
data = pd.DataFrame(({
    'Titles':pd.Series(list_titles),
    'Modules':pd.Series(list_modules),
    'Instructurs':pd.Series(list_instructors_name)}
))
data
# Out:
#                                       Titles  \
# 0  Networking in Google Cloud Specialization
#
#                                              Modules  \
# 0  Google Cloud Fundamentals: Core Infrastructure...
#
#                                          Instructurs
# 0  Google Cloud TrainingGoogle Cloud1,482 Courses...

# %% [markdown]
# ## 4.1 Manual Scripping

# %%
# Buat list unutk menampung nilai
list_titles = []
list_modules = []
list_instructors_name = []

# sediakan url
url = df_raw['url'][238]

# akses website
driver.get(url)

# extract html
html = driver.page_source

# Parsing html
soup = BeautifulSoup(html, 'html.parser') 

# 1. Mengambil title course
title = soup.find('h1')
list_titles.append(title.get_text())
list_titles = ','.join(list_titles)

# 2. Mengambil nama module
modules = soup.find_all('h3', {'class':'cds-119'})
for module in modules:
    list_modules.append(module.get_text())

# Join semua data menjadi 1 baris
list_modules = ','.join(list_modules)

# Mengambil nama instruktur
instructor_name = soup.find_all('div', {'class':'css-1f454bp'})
for name in instructor_name:
    list_instructors_name.append(name.get_text())

# Join semua data menjadi 1 baris
list_instructors_name = ','.join(list_instructors_name)

new_rows = {'Titles': list_titles, 'Modules':list_modules, 'Instructurs':list_instructors_name}

data = data.append(new_rows, ignore_index=True)

data
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_30416\1529605106.py:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(new_rows, ignore_index=True)
#                                                 Titles  \
# 0            Networking in Google Cloud Specialization
# 1    Two Speed IT: How Companies Can Surf the Digit...
# 2                Fundamentals of Network Communication
# 3    Design a User Experience for Social Good & Pre...
# 4                Building Database Applications in PHP
# ..                                                 ...
# 234   Data Science: Foundations using R Specialization
# 235          IBM Data Science Professional Certificate
# 236                        Data Science Specialization
# 237                 Introduction to Physical Chemistry
# 238  Introduction to Chemistry:  Structures and Sol...
#
#                                                Modules  \
# 0    Google Cloud Fundamentals: Core Infrastructure...
# 1    Introduction,IT and the CIO in the Digital Wor...
# 2    Communication Networks and Services,Layered Ar...
# 3    Design for social good and strengthen your por...
# 4    PHP Objects,Connecting PHP and MySQL,PHP Cooki...
# ..                                                 ...
# 234  The Data Scientist’s Toolbox,R Programming,Get...
# 235  Get exclusive access to career resources upon ...
# 236  The Data Scientist’s Toolbox,R Programming,Get...
# 237  Thermodynamics I,Thermodynamics II,Virtual Lab...
# 238  Review Videos (I),light,Quantum Number, Lewis ...
#
#                                            Instructurs
# 0    Google Cloud TrainingGoogle Cloud1,482 Courses...
# 1    Antoine GourévitchCentraleSupélec1 Course•21,6...
# 2    Xiaobo ZhouUniversity of Colorado System4 Cour...
# 3    Top InstructorGoogle Career CertificatesGoogle...
# 4    Charles Russell SeveranceUniversity of Michiga...
# ..                                                 ...
# 234  Roger D. Peng, PhDJohns Hopkins University37 C...
# 235  IBM Skills Network TeamIBM58 Courses•840,269 l...
# 236  Roger D. Peng, PhDJohns Hopkins University37 C...
# 237  Patrick J O'Malley, D.ScUniversity of Manchest...
# 238  Prof. Dorian A. CanelasDuke University2 Course...
#
# [239 rows x 3 columns]

# %%
import pandas as pd

# %%
data.to_csv('data_scrapping.csv')

# %%
df_script = pd.read_csv('data_scrapping.csv')

# %%
df_script['']

# %%
df_script
# Out:
#      Unnamed: 0                                             Titles  \
# 0             0          Networking in Google Cloud Specialization
# 1             1  Two Speed IT: How Companies Can Surf the Digit...
# 2             2              Fundamentals of Network Communication
# 3             3  Design a User Experience for Social Good & Pre...
# 4             4              Building Database Applications in PHP
# ..          ...                                                ...
# 234         234   Data Science: Foundations using R Specialization
# 235         235          IBM Data Science Professional Certificate
# 236         236                        Data Science Specialization
# 237         237                 Introduction to Physical Chemistry
# 238         238  Introduction to Chemistry:  Structures and Sol...
#
#                                                Modules  \
# 0    Google Cloud Fundamentals: Core Infrastructure...
# 1    Introduction,IT and the CIO in the Digital Wor...
# 2    Communication Networks and Services,Layered Ar...
# 3    Design for social good and strengthen your por...
# 4    PHP Objects,Connecting PHP and MySQL,PHP Cooki...
# ..                                                 ...
# 234  The Data Scientist’s Toolbox,R Programming,Get...
# 235  Get exclusive access to career resources upon ...
# 236  The Data Scientist’s Toolbox,R Programming,Get...
# 237  Thermodynamics I,Thermodynamics II,Virtual Lab...
# 238  Review Videos (I),light,Quantum Number, Lewis ...
#
#                                            Instructurs
# 0    Google Cloud TrainingGoogle Cloud1,482 Courses...
# 1    Antoine GourévitchCentraleSupélec1 Course•21,6...
# 2    Xiaobo ZhouUniversity of Colorado System4 Cour...
# 3    Top InstructorGoogle Career CertificatesGoogle...
# 4    Charles Russell SeveranceUniversity of Michiga...
# ..                                                 ...
# 234  Roger D. Peng, PhDJohns Hopkins University37 C...
# 235  IBM Skills Network TeamIBM58 Courses•840,269 l...
# 236  Roger D. Peng, PhDJohns Hopkins University37 C...
# 237  Patrick J O'Malley, D.ScUniversity of Manchest...
# 238  Prof. Dorian A. CanelasDuke University2 Course...
#
# [239 rows x 4 columns]

# %%
# Assign final dataset
df = df_raw 

# Insert column Modules and Instructurs 
df['modules'] = df_script['Modules']
df['instructor'] = df_script['Instructurs']

# Display final dataset
df
# Out:
#                                                    url  \
# 0    https://www.coursera.org/specializations/netwo...
# 1            https://www.coursera.org/learn/2-speed-it
# 2    https://www.coursera.org/learn/fundamentals-ne...
# 3        https://www.coursera.org/learn/ux-design-jobs
# 4    https://www.coursera.org/learn/database-applic...
# ..                                                 ...
# 218  https://www.coursera.org/specializations/data-...
# 219  https://www.coursera.org/professional-certific...
# 220  https://www.coursera.org/specializations/jhu-d...
# 221  https://www.coursera.org/learn/physical-chemistry
# 222     https://www.coursera.org/learn/basic-chemistry
#
#                                                  title  \
# 0            Networking in Google Cloud Specialization
# 1    Two Speed IT: How Companies Can Surf the Digit...
# 2                Fundamentals of Network Communication
# 3    Design a User Experience for Social Good & Pre...
# 4                Building Database Applications in PHP
# ..                                                 ...
# 218   Data Science: Foundations using R Specialization
# 219          IBM Data Science Professional Certificate
# 220                        Data Science Specialization
# 221                 Introduction to Physical Chemistry
# 222  Introduction to Chemistry:  Structures and Sol...
#
#     associated-university-institution-company                       type  \
# 0                                Google Cloud            specializations
# 1                             CentraleSupélec                     course
# 2               University of Colorado System                     course
# 3                                      Google                     course
# 4                      University of Michigan                     course
# ..                                        ...                        ...
# 218                                         -            specializations
# 219                        IBM Skills Network  professional certificates
# 220                                         -            specializations
# 221                  University of Manchester                     course
# 222                           Duke University                     course
#
#                                                  image  \
# 0    https://s3.amazonaws.com/coursera_assets/meta_...
# 1    https://s3.amazonaws.com/coursera_assets/meta_...
# 2    https://s3.amazonaws.com/coursera_assets/meta_...
# 3    https://s3.amazonaws.com/coursera_assets/meta_...
# 4    https://s3.amazonaws.com/coursera_assets/meta_...
# ..                                                 ...
# 218  https://s3.amazonaws.com/coursera_assets/meta_...
# 219  https://s3.amazonaws.com/coursera_assets/meta_...
# 220  https://s3.amazonaws.com/coursera_assets/meta_...
# 221  https://s3.amazonaws.com/coursera_assets/meta_...
# 222  https://s3.amazonaws.com/coursera_assets/meta_...
#
#               category-subject-area certificate-is-available  \
# 0                        Networking    Shareable Certificate
# 1               Business Essentials    Shareable Certificate
# 2    Computer Security and Networks    Shareable Certificate
# 3                Design and Product    Shareable Certificate
# 4        Mobile and Web Development    Shareable Certificate
# ..                              ...                      ...
# 218                   Data Analysis    Shareable Certificate
# 219                   Data Analysis    Shareable Certificate
# 220                   Data Analysis    Shareable Certificate
# 221                       Chemistry    Shareable Certificate
# 222                       Chemistry    Shareable Certificate
#
#                                            description  \
# 0    This specialization gives participants broad s...
# 1    Transform or disappear, the Darwinism of IT: I...
# 2    In this course, we trace the evolution of netw...
# 3    Design a User Experience for Social Good and P...
# 4    In this course, we'll look at the object orien...
# ..                                                 ...
# 218  Ask the right questions, manipulate data sets,...
# 219  Data science is one of the hottest professions...
# 220  Ask the right questions, manipulate data sets,...
# 221  Chemical reactions underpin the production of ...
# 222  This is an introductory course for students wi...
#
#                                 duration language               level  \
# 0     Approximately 4 months to complete  English  Intermediate Level
# 1           Approx. 14 hours to complete  English                   -
# 2           Approx. 15 hours to complete  English  Intermediate Level
# 3           Approx. 71 hours to complete  English      Beginner Level
# 4           Approx. 24 hours to complete  English  Intermediate Level
# ..                                   ...      ...                 ...
# 218   Approximately 5 months to complete  English      Beginner Level
# 219  Approximately 11 months to complete  English      Beginner Level
# 220  Approximately 11 months to complete  English      Beginner Level
# 221         Approx. 19 hours to complete  English                   -
# 222         Approx. 17 hours to complete  English      Beginner Level
#
#     prerequisites price rating  \
# 0               -  free    4.8
# 1               -  free    4.3
# 2               -  free    4.6
# 3               -  free    4.8
# 4               -  free    4.9
# ..            ...   ...    ...
# 218             -  free    4.6
# 219             -  free    4.6
# 220             -  free    4.5
# 221             -  free    4.7
# 222             -  free    4.7
#
#                                               syllabus             timestamp  \
# 0                                                    -  2022-07-29T23:58:34Z
# 1    Introduction ~.~ Start here! ~.~ IT and the CI...  2022-07-29T23:58:34Z
# 2    Communication Networks and Services ~.~ This m...  2022-07-29T23:58:54Z
# 3    Starting the UX design process: empathize, def...  2022-07-29T23:59:20Z
# 4    PHP Objects ~.~ We look at the object oriented...  2022-07-29T23:59:20Z
# ..                                                 ...                   ...
# 218                                                  -  2022-07-30T00:45:32Z
# 219                                                  -  2022-07-30T00:45:32Z
# 220                                                  -  2022-07-30T00:45:32Z
# 221  Thermodynamics I ~.~ This module explores ther...  2022-07-30T00:45:41Z
# 222  light ~.~ We will cover introduction to light,...  2022-07-30T00:45:42Z
#
#                                                modules  \
# 0    Google Cloud Fundamentals: Core Infrastructure...
# 1    Introduction,IT and the CIO in the Digital Wor...
# 2    Communication Networks and Services,Layered Ar...
# 3    Design for social good and strengthen your por...
# 4    PHP Objects,Connecting PHP and MySQL,PHP Cooki...
# ..                                                 ...
# 218  Apresentação e Introdução ao Curso,Introdução ...
# 219  Working with Multiple Worksheets & Workbooks,T...
# 220  Filtering Data Using Queries,Vector analysis,R...
# 221  Find Your Audience With Segmentation,Analytics...
# 222  Critical Core of Excel,Performing calculations...
#
#                                             instructor
# 0    Google Cloud TrainingGoogle Cloud1,482 Courses...
# 1    Antoine GourévitchCentraleSupélec1 Course•21,6...
# 2    Xiaobo ZhouUniversity of Colorado System4 Cour...
# 3    Top InstructorGoogle Career CertificatesGoogle...
# 4    Charles Russell SeveranceUniversity of Michiga...
# ..                                                 ...
# 218  Top InstructorFabio KonUniversidade de São Pau...
# 219  Nicky BullMacquarie University25 Courses•1,301...
# 220  Top InstructorDon BoyesUniversity of Toronto4 ...
# 221  Anke AudenaertMeta35 Courses•657,734 learners,...
# 222  Nicky BullMacquarie University25 Courses•1,301...
#
# [223 rows x 18 columns]

# %% [markdown]
# **Insight**
# - There are several inactive urls which include urls in rows : 30, 31, 33, 74, 75, 96, 102, 140, 164, 184, 187, 195, 196, 211, 212, 233.
# - There is one row with arabic letter in row 32.

# %% [markdown]
# ## 4.2 Function untuk mengambil Semua data

# %%
# Buat list unutk menampung nilai
list_titles = []
list_modules = []
list_instructors_name = []

# sediakan url
url = df_raw['url'][0]

# akses website
driver.get(url)

# extract html
html = driver.page_source

# Parsing html
soup = BeautifulSoup(html, 'html.parser') 

# 1. Mengambil title course
title = soup.find('h1')
list_titles.append(title.get_text())
list_titles = ','.join(list_titles)

# 2. Mengambil nama module
modules = soup.find_all('h3', {'class':'cds-119'})
for module in modules:
    list_modules.append(module.get_text())

# Join semua data menjadi 1 baris
list_modules = ','.join(list_modules)

# Mengambil nama instruktur
instructor_name = soup.find_all('div', {'class':'css-1f454bp'})
for name in instructor_name:
    list_instructors_name.append(name.get_text())

# Join semua data menjadi 1 baris
list_instructors_name = ','.join(list_instructors_name)

# Gabungkan di dataframe
df2 = pd.DataFrame(({
    'Titles':pd.Series(list_titles),
    'Modules':pd.Series(list_modules),
    'Instructurs':pd.Series(list_instructors_name)}
))
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[105], line 10
#       7 url = df_raw['url'][0]
#       9 # akses website
# ---> 10 driver.get(url)
#      12 # extract html
#      13 html = driver.page_source
#
# NameError: name 'driver' is not defined

# %%
def get_data(data1, data2):

    # Buat list unutk menampung nilai
    list_titles = []
    list_modules = []
    list_instructors_name = []

    # Variable untuk looping
    x = 0

    for i in data1['url'][0:3]:
        for y in data2:
                
            # sediakan url
            url = df_raw['url'][x]

            # akses website
            driver.get(url)

            # extract html
            html = driver.page_source

            # Parsing html
            soup = BeautifulSoup(html, 'html.parser') 

            # 1. Mengambil title course
            title = soup.find('h1')
            list_titles.append(title.get_text())

            # 2. Mengambil nama module
            modules = soup.find_all('h3', {'class':'cds-119'})
            for module in modules:
                list_modules.append(module.get_text())

            # Mengambil nama instruktur
            instructor_name = soup.find_all('div', {'class':'css-1f454bp'})
            for name in instructor_name:
                list_instructors_name.append(name.get_text())

            # Join semua data menjadi 1 baris
            list_instructors_name = ','.join(list_instructors_name)

            new_rows = {'Titles': list_titles, 'Modules':list_modules, 'Instructurs':list_instructors_name}
            data2 = data2.append(new_rows, ignore_index=True)

            list_titles = []
            list_modules = []
            list_instructors_name = []
            
            x += 1
            

            # df['Titles'] = pd.Series(list_titles)
            # df['Modules'] = pd.Series(list_modules)
            
            
        #     # new_rows = {'Titles': list_titles, 'Modules':list_modules}
        # df = df.append(list_titles, ignore_index=True)
        # df = df.append(list_modules, ignore_index=True)

# %%
get_data(df_raw, df2)
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_30416\3132151435.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data2 = data2.append(new_rows, ignore_index=True)
# C:\Users\andre\AppData\Local\Temp\ipykernel_30416\3132151435.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data2 = data2.append(new_rows, ignore_index=True)
# C:\Users\andre\AppData\Local\Temp\ipykernel_30416\3132151435.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data2 = data2.append(new_rows, ignore_index=True)
# C:\Users\andre\AppData\Local\Temp\ipykernel_30416\3132151435.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data2 = data2.append(new_rows, ignore_index=True)
# C:\Users\andre\AppData\Local\Temp\ipykernel_30416\3132151435.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data2 = data2.append(new_rows, ignore_index=True)
# C:\Users\andre\AppData\Local\Temp\ipykernel_30416\3132151435.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data2 = data2.append(new_rows, ignore_index=True)
# C:\Users\andre\AppData\Local\Temp\ipykernel_30416\3132151435.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data2 = data2.append(new_rows, ignore_index=True)
# C:\Users\andre\AppData\Local\Temp\ipykernel_30416\3132151435.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data2 = data2.append(new_rows, ignore_index=True)
# C:\Users\andre\AppData\Local\Temp\ipykernel_30416\3132151435.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data2 = data2.append(new_rows, ignore_index=True)

# %%
data2
# Out:
#                                       Titles  \
# 0  Networking in Google Cloud Specialization
#
#                                              Modules  \
# 0  Google Cloud Fundamentals: Core Infrastructure...
#
#                                          Instructurs
# 0  Google Cloud TrainingGoogle Cloud1,480 Courses...

# %%
# Buat list unutk menampung nilai
list_titles = []
list_modules = []

def get_data(data):
        
    # Buat Dataframe
    df = pd.DataFrame(({
        'Titles':pd.Series(),
        'Modules':pd.Series()}))

    # Variable untuk looping
    x = 0

    for i in data2['url'][0:10]:   
        # sediakan url
        url = df_raw['url'][x]

        # akses website
        driver.get(url)

        # extract html
        html = driver.page_source

        # Parsing html
        soup = BeautifulSoup(html, 'html.parser') 

        # 1. Mengambil title course
        title = soup.find('h1')
        list_titles.append(title.get_text())

        # 2. Mengambil nama module
        modules = soup.find_all('h3', {'class':'cds-119'})
        for module in modules:
            list_modules.append(module.get_text())
        x += 1
        

        # df['Titles'] = pd.Series(list_titles)
        # df['Modules'] = pd.Series(list_modules)
        
        
    #     # new_rows = {'Titles': list_titles, 'Modules':list_modules}
    # df = df.append(list_titles, ignore_index=True)
    # df = df.append(list_modules, ignore_index=True)

# %%
# Buat list unutk menampung nilai
list_titles = []
list_modules = []
list_instructors_name = []

def get_data(data):
        
    # Buat Dataframe
    df = pd.DataFrame(({
        'Titles':pd.Series(),
        'Modules':pd.Series()}))

    # Variable untuk looping
    x = 0

    for i in data['url'][0:10]:   
        # sediakan url
        url = df_raw['url'][x]

        # akses website
        driver.get(url)

        # extract html
        html = driver.page_source

        # Parsing html
        soup = BeautifulSoup(html, 'html.parser') 

        # 1. Mengambil title course
        title = soup.find('h1')
        list_titles.append(title.get_text())

        # 2. Mengambil nama module
        modules = soup.find_all('h3', {'class':'cds-119'})
        for module in modules:
            list_modules.append(module.get_text())

        # 3. Mengambil nama instruktur
        instructor_name = soup.find_all('div', {'class':'css-1f454bp'})
        for name in instructor_name:
            list_instructors_name.append(name.get_text())
        x += 1
        

        # df['Titles'] = pd.Series(list_titles)
        # df['Modules'] = pd.Series(list_modules)
           
        # new_rows = {'Titles': list_titles, 'Modules':list_modules}
        # df = df.append(new_rows, ignore_index=True)
    df = df.append(list_titles, ignore_index=True)
    df = df.append(list_modules, ignore_index=True)
    df = df.append(list_instructors_name, ignore_index=True)

# %%
get_data(df_raw)
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_35996\153619564.py:10: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   'Titles':pd.Series(),
# C:\Users\andre\AppData\Local\Temp\ipykernel_35996\153619564.py:11: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   'Modules':pd.Series()}))
# C:\Users\andre\AppData\Local\Temp\ipykernel_35996\153619564.py:50: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(list_titles, ignore_index=True)
# C:\Users\andre\AppData\Local\Temp\ipykernel_35996\153619564.py:51: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(list_modules, ignore_index=True)
# C:\Users\andre\AppData\Local\Temp\ipykernel_35996\153619564.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(list_instructors_name, ignore_index=True)

# %%
df
# Out:
#                                               Titles  \
# 0  Two Speed IT: How Companies Can Surf the Digit...
# 1  Two Speed IT: How Companies Can Surf the Digit...
#
#                                              Modules
# 0  Introduction,IT and the CIO in the Digital Wor...
# 1  Introduction,IT and the CIO in the Digital Wor...

# %%
list_titles
# Out:
# ['Networking in Google Cloud Specialization',
#  'Two Speed IT: How Companies Can Surf the Digital Wave, a BCG Perspective',
#  'Fundamentals of Network Communication',
#  'Design a User Experience for Social Good & Prepare for Jobs',
#  'Building Database Applications in PHP',
#  'Web Design: Wireframes to Prototypes',
#  'Build Wireframes and Low-Fidelity Prototypes',
#  'Introduction to C# Programming and Unity',
#  'Virtual Reality Specialization',
#  'C++ Programming for Unreal Game Development Specialization']

# %%
list_modules
# Out:
# ['Google Cloud Fundamentals: Core Infrastructure',
#  'Networking in Google Cloud: Defining and Implementing Networks',
#  'Networking in Google Cloud: Hybrid Connectivity and Network Management',
#  'Instructor',
#  'Offered by',
#  'More questions',
#  'Introduction',
#  'IT and the CIO in the Digital World',
#  'Steer the Balance Sheet',
#  'Market and Sell Products',
#  'Run the Factories',
#  'Manage Human Resources',
#  'Transform or Disappear',
#  'Instructors',
#  'Offered by',
#  "Recommended if you're interested in Business Essentials",
#  'More questions',
#  'Communication Networks and Services',
#  'Layered Architectures ',
#  'Socket API & Digital Transmissions',
#  'Error Control',
#  'course project - fundamentals of network communication',
#  'Instructor',
#  'Offered by',
#  "Recommended if you're interested in Computer Security and Networks",
#  'More questions',
#  'Design for social good and strengthen your portfolio',
#  'Build a professional presence',
#  'Finding a UX job',
#  'Instructor',
#  'Offered by',
#  "Recommended if you're interested in Design and Product",
#  'More questions',
#  'PHP Objects',
#  'Connecting PHP and MySQL',
#  'PHP Cookies and Sessions',
#  'PHP Redirect, Routing, and Authentication',
#  'Building a CRUD Application',
#  'Instructor',
#  'Offered by',
#  "Recommended if you're interested in Mobile and Web Development",
#  'More questions',
#  'Course Overview',
#  'Not Getting Caught up in the Details: Wireframes',
#  'Finally, Make it Beautiful: The Mockup Phase',
#  'An Excursion to Codelandia',
#  'Putting it all Together: Final Presentation',
#  'Instructor',
#  'Offered by',
#  "Recommended if you're interested in Music and Art",
#  'More questions',
#  'Storyboarding and wireframing ',
#  'Creating paper and digital wireframes',
#  'Building low-fidelity prototypes',
#  'Instructor',
#  'Offered by',
#  "Recommended if you're interested in Design and Product",
#  'More questions',
#  'Starting to Program',
#  'Data Types, Variables, and Constants',
#  'Classes and Objects',
#  'Unity 2D Basics',
#  'Instructor',
#  'Offered by',
#  "Recommended if you're interested in Software Development",
#  'More questions',
#  'Introduction to Virtual Reality',
#  '3D Models for Virtual Reality',
#  '3D Interaction Design in Virtual Reality',
#  'Building Interactive 3D Characters and Social VR',
#  'Making Your First Virtual Reality Game',
#  'Instructors',
#  'Offered by',
#  'More questions',
#  'Introduction to C++ Programming and Unreal',
#  'More C++ Programming and Unreal',
#  'C++ Class Development',
#  'Intermediate Object-Oriented Programming for Unreal Games',
#  'Instructor',
#  'Offered by',
#  'More questions']

# %%
list_instructors_name
# Out:
# ['Google Cloud TrainingGoogle Cloud1,480 Courses•2,614,781 learners',
#  'Google CloudLearn moreCloseOffered byGoogle CloudWe help millions of organizations empower their employees, serve their customers, and build what’s next for their businesses with innovative technology created in—and for—the cloud. Our products are engineered for security, reliability, and scalability, running the full stack from infrastructure to applications to devices and hardware. Our teams are dedicated to helping customers apply our technologies to create success.OK',
#  'Antoine GourévitchCentraleSupélec1 Course•21,696 learners',
#  'Vanessa LyonCentraleSupélec1 Course•21,696 learners',
#  'Eric BaudsonCentraleSupélec1 Course•21,696 learners',
#  'CentraleSupélecLearn moreCloseOffered byCentraleSupélecCentraleSupélec is the result of the merger of the Ecole Centrale Paris and the Supélec. The collaboration between the two Colleges of engineering begun in 1969 with the introduction of the joint competitive entrance exam. Since 2009, the Ecole Centrale Paris and Supélec have continually strengthened their partnerships and collaborations with the aim of encompassing the whole of their activities (engineering education, research and post graduate programs) and confirmed their shared values of excellence, innovation, entrepreneurship, internationalization and leadership. Today CentraleSupélec aims to become a reference in the field of engineering and systems sciences and a leading engineering College in the area of higher education and research, ranked amongst the best institutions in the world. OK',
#  'Xiaobo ZhouUniversity of Colorado System4 Courses•129,072 learners',
#  'University of Colorado SystemLearn moreCloseOffered byUniversity of Colorado SystemThe University of Colorado is a recognized leader in higher education on the national and global stage.  We collaborate to meet the diverse needs of our students and communities.  We promote innovation, encourage discovery and support the extension of knowledge in ways unique to the state of Colorado and beyond.OK',
#  'Top InstructorGoogle Career CertificatesGoogle324 Courses•10,119,201 learners',
#  "GoogleLearn moreCloseOffered byGoogleGrow with Google is an initiative that draws on Google's decades-long history of building products, platforms, and services that help people and businesses grow. We aim to help everyone – those who make up the workforce of today and the students who will drive the workforce of tomorrow – access the best of Google’s training and tools to grow their skills, careers, and businesses.OK",
#  'Charles Russell SeveranceUniversity of Michigan60 Courses•4,251,830 learners',
#  'University of MichiganLearn moreCloseOffered byUniversity of MichiganThe mission of the University of Michigan is to serve the people of Michigan and the world through preeminence in creating, communicating, preserving and applying knowledge, art, and academic values, and in developing leaders and citizens who will challenge the present and enrich the future.OK',
#  'Roman Jaster2 Courses•88,935 learners',
#  'California Institute of the ArtsLearn moreCloseOffered byCalifornia Institute of the ArtsCalArts has earned an international reputation as the leading college of the visual and performing arts in the United States. Offering rigorous undergraduate and graduate degree programs through six schools—Art, Critical Studies, Dance, Film/Video, Music, and Theater—CalArts has championed creative excellence, critical reflection, and the development of new forms and expressions.\nOK',
#  'Top InstructorGoogle Career CertificatesGoogle324 Courses•10,119,201 learners',
#  "GoogleLearn moreCloseOffered byGoogleGrow with Google is an initiative that draws on Google's decades-long history of building products, platforms, and services that help people and businesses grow. We aim to help everyone – those who make up the workforce of today and the students who will drive the workforce of tomorrow – access the best of Google’s training and tools to grow their skills, careers, and businesses.OK",
#  'Dr. Tim "Dr. T" ChamillardUniversity of Colorado System20 Courses•217,587 learners',
#  'University of Colorado SystemLearn moreCloseOffered byUniversity of Colorado SystemThe University of Colorado is a recognized leader in higher education on the national and global stage.  We collaborate to meet the diverse needs of our students and communities.  We promote innovation, encourage discovery and support the extension of knowledge in ways unique to the state of Colorado and beyond.OK',
#  'Prof Marco GilliesUniversity of London14 Courses•539,890 learners',
#  'Prof Sylvia Xueni PanUniversity of London5 Courses•128,307 learners',
#  'University of LondonLearn moreCloseOffered byUniversity of LondonThe University of London is a federal University which includes 17 world leading Colleges. With extensive experience in distance learning since 1858, University of London has enriched the lives of thousands of students, delivering high quality degrees across the globe. Today, University of London is a global leader in flexible study, offering degree programmes to over 45,000 students in over 190 countries, delivering world-leading research across the world. To find out more about University of London, visit www.london.ac.uk OK',
#  'Goldsmiths, University of LondonLearn moreCloseOffered byGoldsmiths, University of LondonChampioning research-rich degrees that provoke thought, stretch the imagination and tap into tomorrow’s world, at Goldsmiths we’re asking the questions that matter now in subjects as diverse as the arts and humanities, social sciences, cultural studies, computing, and entrepreneurial business and management. We are a community defined by its people: innovative in spirit, analytical in approach and open to all.OK',
#  'Dr. Tim "Dr. T" ChamillardUniversity of Colorado System20 Courses•217,587 learners',
#  'University of Colorado SystemLearn moreCloseOffered byUniversity of Colorado SystemThe University of Colorado is a recognized leader in higher education on the national and global stage.  We collaborate to meet the diverse needs of our students and communities.  We promote innovation, encourage discovery and support the extension of knowledge in ways unique to the state of Colorado and beyond.OK']

# %% [markdown]
# # 5. Data Cleaning

# %%
# Displaying final dataset
df
# Out:
#                                                    url  \
# 0    https://www.coursera.org/specializations/netwo...
# 1            https://www.coursera.org/learn/2-speed-it
# 2    https://www.coursera.org/learn/fundamentals-ne...
# 3        https://www.coursera.org/learn/ux-design-jobs
# 4    https://www.coursera.org/learn/database-applic...
# ..                                                 ...
# 218  https://www.coursera.org/specializations/data-...
# 219  https://www.coursera.org/professional-certific...
# 220  https://www.coursera.org/specializations/jhu-d...
# 221  https://www.coursera.org/learn/physical-chemistry
# 222     https://www.coursera.org/learn/basic-chemistry
#
#                                                  title  \
# 0            Networking in Google Cloud Specialization
# 1    Two Speed IT: How Companies Can Surf the Digit...
# 2                Fundamentals of Network Communication
# 3    Design a User Experience for Social Good & Pre...
# 4                Building Database Applications in PHP
# ..                                                 ...
# 218   Data Science: Foundations using R Specialization
# 219          IBM Data Science Professional Certificate
# 220                        Data Science Specialization
# 221                 Introduction to Physical Chemistry
# 222  Introduction to Chemistry:  Structures and Sol...
#
#     associated-university-institution-company                       type  \
# 0                                Google Cloud            specializations
# 1                             CentraleSupélec                     course
# 2               University of Colorado System                     course
# 3                                      Google                     course
# 4                      University of Michigan                     course
# ..                                        ...                        ...
# 218                                         -            specializations
# 219                        IBM Skills Network  professional certificates
# 220                                         -            specializations
# 221                  University of Manchester                     course
# 222                           Duke University                     course
#
#                                                  image  \
# 0    https://s3.amazonaws.com/coursera_assets/meta_...
# 1    https://s3.amazonaws.com/coursera_assets/meta_...
# 2    https://s3.amazonaws.com/coursera_assets/meta_...
# 3    https://s3.amazonaws.com/coursera_assets/meta_...
# 4    https://s3.amazonaws.com/coursera_assets/meta_...
# ..                                                 ...
# 218  https://s3.amazonaws.com/coursera_assets/meta_...
# 219  https://s3.amazonaws.com/coursera_assets/meta_...
# 220  https://s3.amazonaws.com/coursera_assets/meta_...
# 221  https://s3.amazonaws.com/coursera_assets/meta_...
# 222  https://s3.amazonaws.com/coursera_assets/meta_...
#
#               category-subject-area certificate-is-available  \
# 0                        Networking    Shareable Certificate
# 1               Business Essentials    Shareable Certificate
# 2    Computer Security and Networks    Shareable Certificate
# 3                Design and Product    Shareable Certificate
# 4        Mobile and Web Development    Shareable Certificate
# ..                              ...                      ...
# 218                   Data Analysis    Shareable Certificate
# 219                   Data Analysis    Shareable Certificate
# 220                   Data Analysis    Shareable Certificate
# 221                       Chemistry    Shareable Certificate
# 222                       Chemistry    Shareable Certificate
#
#                                            description  \
# 0    This specialization gives participants broad s...
# 1    Transform or disappear, the Darwinism of IT: I...
# 2    In this course, we trace the evolution of netw...
# 3    Design a User Experience for Social Good and P...
# 4    In this course, we'll look at the object orien...
# ..                                                 ...
# 218  Ask the right questions, manipulate data sets,...
# 219  Data science is one of the hottest professions...
# 220  Ask the right questions, manipulate data sets,...
# 221  Chemical reactions underpin the production of ...
# 222  This is an introductory course for students wi...
#
#                                 duration language               level  \
# 0     Approximately 4 months to complete  English  Intermediate Level
# 1           Approx. 14 hours to complete  English                   -
# 2           Approx. 15 hours to complete  English  Intermediate Level
# 3           Approx. 71 hours to complete  English      Beginner Level
# 4           Approx. 24 hours to complete  English  Intermediate Level
# ..                                   ...      ...                 ...
# 218   Approximately 5 months to complete  English      Beginner Level
# 219  Approximately 11 months to complete  English      Beginner Level
# 220  Approximately 11 months to complete  English      Beginner Level
# 221         Approx. 19 hours to complete  English                   -
# 222         Approx. 17 hours to complete  English      Beginner Level
#
#     prerequisites price rating  \
# 0               -  free    4.8
# 1               -  free    4.3
# 2               -  free    4.6
# 3               -  free    4.8
# 4               -  free    4.9
# ..            ...   ...    ...
# 218             -  free    4.6
# 219             -  free    4.6
# 220             -  free    4.5
# 221             -  free    4.7
# 222             -  free    4.7
#
#                                               syllabus             timestamp  \
# 0                                                    -  2022-07-29T23:58:34Z
# 1    Introduction ~.~ Start here! ~.~ IT and the CI...  2022-07-29T23:58:34Z
# 2    Communication Networks and Services ~.~ This m...  2022-07-29T23:58:54Z
# 3    Starting the UX design process: empathize, def...  2022-07-29T23:59:20Z
# 4    PHP Objects ~.~ We look at the object oriented...  2022-07-29T23:59:20Z
# ..                                                 ...                   ...
# 218                                                  -  2022-07-30T00:45:32Z
# 219                                                  -  2022-07-30T00:45:32Z
# 220                                                  -  2022-07-30T00:45:32Z
# 221  Thermodynamics I ~.~ This module explores ther...  2022-07-30T00:45:41Z
# 222  light ~.~ We will cover introduction to light,...  2022-07-30T00:45:42Z
#
#                                                modules  \
# 0    Google Cloud Fundamentals: Core Infrastructure...
# 1    Introduction,IT and the CIO in the Digital Wor...
# 2    Communication Networks and Services,Layered Ar...
# 3    Design for social good and strengthen your por...
# 4    PHP Objects,Connecting PHP and MySQL,PHP Cooki...
# ..                                                 ...
# 218  Apresentação e Introdução ao Curso,Introdução ...
# 219  Working with Multiple Worksheets & Workbooks,T...
# 220  Filtering Data Using Queries,Vector analysis,R...
# 221  Find Your Audience With Segmentation,Analytics...
# 222  Critical Core of Excel,Performing calculations...
#
#                                             instructor
# 0    Google Cloud TrainingGoogle Cloud1,482 Courses...
# 1    Antoine GourévitchCentraleSupélec1 Course•21,6...
# 2    Xiaobo ZhouUniversity of Colorado System4 Cour...
# 3    Top InstructorGoogle Career CertificatesGoogle...
# 4    Charles Russell SeveranceUniversity of Michiga...
# ..                                                 ...
# 218  Top InstructorFabio KonUniversidade de São Pau...
# 219  Nicky BullMacquarie University25 Courses•1,301...
# 220  Top InstructorDon BoyesUniversity of Toronto4 ...
# 221  Anke AudenaertMeta35 Courses•657,734 learners,...
# 222  Nicky BullMacquarie University25 Courses•1,301...
#
# [223 rows x 18 columns]

# %% [markdown]
# ## 5.1 Drop inactive rows

# %%
# Drop inactive url rows
df.drop(index=[30, 31, 33, 74, 75, 96, 102, 140, 164, 184, 187, 195, 196, 211], inplace=True)

# Reset index
df.reset_index(inplace=True)

# Drop index columns
df.drop('index',axis=1,inplace=True)

# %%
# Drop another column
df.drop(index=27, inplace=True)

# Reset index
df.reset_index(inplace=True)

# Drop index columns
df.drop('index',axis=1,inplace=True)

# %% [markdown]
# ## 5.1 Rename Columns Name

# %%
# Rename several columns name
df = df.rename(columns={
                        'associated-university-institution-company': 'association',
                        'category-subject-area': 'category',
                        'certificate-is-available': 'certificate_type'
                        })

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.coursera.org/specializations/netwo...
# 1          https://www.coursera.org/learn/2-speed-it
# 2  https://www.coursera.org/learn/fundamentals-ne...
# 3      https://www.coursera.org/learn/ux-design-jobs
# 4  https://www.coursera.org/learn/database-applic...
#
#                                                title  \
# 0          Networking in Google Cloud Specialization
# 1  Two Speed IT: How Companies Can Surf the Digit...
# 2              Fundamentals of Network Communication
# 3  Design a User Experience for Social Good & Pre...
# 4              Building Database Applications in PHP
#
#                      association             type  \
# 0                   Google Cloud  specializations
# 1                CentraleSupélec           course
# 2  University of Colorado System           course
# 3                         Google           course
# 4         University of Michigan           course
#
#                                                image  \
# 0  https://s3.amazonaws.com/coursera_assets/meta_...
# 1  https://s3.amazonaws.com/coursera_assets/meta_...
# 2  https://s3.amazonaws.com/coursera_assets/meta_...
# 3  https://s3.amazonaws.com/coursera_assets/meta_...
# 4  https://s3.amazonaws.com/coursera_assets/meta_...
#
#                          category       certificate_type  \
# 0                      Networking  Shareable Certificate
# 1             Business Essentials  Shareable Certificate
# 2  Computer Security and Networks  Shareable Certificate
# 3              Design and Product  Shareable Certificate
# 4      Mobile and Web Development  Shareable Certificate
#
#                                          description  \
# 0  This specialization gives participants broad s...
# 1  Transform or disappear, the Darwinism of IT: I...
# 2  In this course, we trace the evolution of netw...
# 3  Design a User Experience for Social Good and P...
# 4  In this course, we'll look at the object orien...
#
#                              duration language               level  \
# 0  Approximately 4 months to complete  English  Intermediate Level
# 1        Approx. 14 hours to complete  English                   -
# 2        Approx. 15 hours to complete  English  Intermediate Level
# 3        Approx. 71 hours to complete  English      Beginner Level
# 4        Approx. 24 hours to complete  English  Intermediate Level
#
#   prerequisites price rating  \
# 0             -  free    4.8
# 1             -  free    4.3
# 2             -  free    4.6
# 3             -  free    4.8
# 4             -  free    4.9
#
#                                             syllabus             timestamp  \
# 0                                                  -  2022-07-29T23:58:34Z
# 1  Introduction ~.~ Start here! ~.~ IT and the CI...  2022-07-29T23:58:34Z
# 2  Communication Networks and Services ~.~ This m...  2022-07-29T23:58:54Z
# 3  Starting the UX design process: empathize, def...  2022-07-29T23:59:20Z
# 4  PHP Objects ~.~ We look at the object oriented...  2022-07-29T23:59:20Z
#
#                                              modules  \
# 0  Google Cloud Fundamentals: Core Infrastructure...
# 1  Introduction,IT and the CIO in the Digital Wor...
# 2  Communication Networks and Services,Layered Ar...
# 3  Design for social good and strengthen your por...
# 4  PHP Objects,Connecting PHP and MySQL,PHP Cooki...
#
#                                           instructor
# 0  Google Cloud TrainingGoogle Cloud1,482 Courses...
# 1  Antoine GourévitchCentraleSupélec1 Course•21,6...
# 2  Xiaobo ZhouUniversity of Colorado System4 Cour...
# 3  Top InstructorGoogle Career CertificatesGoogle...
# 4  Charles Russell SeveranceUniversity of Michiga...

# %% [markdown]
# ## 5.2 Re-arrange Columns

# %%
# Re-arrange columns position
df = df[['title', 'category', 'type', 'level', 'description', 'price',
    'rating', 'duration', 'language', 'prerequisites', 'syllabus',
    'modules', 'instructor', 'certificate_type', 'association','image', 'url', 'timestamp']]

# Displaying dataset
df
# Out:
#                                                  title  \
# 0            Networking in Google Cloud Specialization
# 1    Two Speed IT: How Companies Can Surf the Digit...
# 2                Fundamentals of Network Communication
# 3    Design a User Experience for Social Good & Pre...
# 4                Building Database Applications in PHP
# ..                                                 ...
# 203   Data Science: Foundations using R Specialization
# 204          IBM Data Science Professional Certificate
# 205                        Data Science Specialization
# 206                 Introduction to Physical Chemistry
# 207  Introduction to Chemistry:  Structures and Sol...
#
#                            category                       type  \
# 0                        Networking            specializations
# 1               Business Essentials                     course
# 2    Computer Security and Networks                     course
# 3                Design and Product                     course
# 4        Mobile and Web Development                     course
# ..                              ...                        ...
# 203                   Data Analysis            specializations
# 204                   Data Analysis  professional certificates
# 205                   Data Analysis            specializations
# 206                       Chemistry                     course
# 207                       Chemistry                     course
#
#                   level                                        description  \
# 0    Intermediate Level  This specialization gives participants broad s...
# 1                     -  Transform or disappear, the Darwinism of IT: I...
# 2    Intermediate Level  In this course, we trace the evolution of netw...
# 3        Beginner Level  Design a User Experience for Social Good and P...
# 4    Intermediate Level  In this course, we'll look at the object orien...
# ..                  ...                                                ...
# 203      Beginner Level  Ask the right questions, manipulate data sets,...
# 204      Beginner Level  Data science is one of the hottest professions...
# 205      Beginner Level  Ask the right questions, manipulate data sets,...
# 206                   -  Chemical reactions underpin the production of ...
# 207      Beginner Level  This is an introductory course for students wi...
#
#     price rating                             duration language prerequisites  \
# 0    free    4.8   Approximately 4 months to complete  English             -
# 1    free    4.3         Approx. 14 hours to complete  English             -
# 2    free    4.6         Approx. 15 hours to complete  English             -
# 3    free    4.8         Approx. 71 hours to complete  English             -
# 4    free    4.9         Approx. 24 hours to complete  English             -
# ..    ...    ...                                  ...      ...           ...
# 203  free    4.6   Approximately 5 months to complete  English             -
# 204  free    4.6  Approximately 11 months to complete  English             -
# 205  free    4.5  Approximately 11 months to complete  English             -
# 206  free    4.7         Approx. 19 hours to complete  English             -
# 207  free    4.7         Approx. 17 hours to complete  English             -
#
#                                               syllabus  \
# 0                                                    -
# 1    Introduction ~.~ Start here! ~.~ IT and the CI...
# 2    Communication Networks and Services ~.~ This m...
# 3    Starting the UX design process: empathize, def...
# 4    PHP Objects ~.~ We look at the object oriented...
# ..                                                 ...
# 203                                                  -
# 204                                                  -
# 205                                                  -
# 206  Thermodynamics I ~.~ This module explores ther...
# 207  light ~.~ We will cover introduction to light,...
#
#                                                modules  \
# 0    Google Cloud Fundamentals: Core Infrastructure...
# 1    Introduction,IT and the CIO in the Digital Wor...
# 2    Communication Networks and Services,Layered Ar...
# 3    Design for social good and strengthen your por...
# 4    PHP Objects,Connecting PHP and MySQL,PHP Cooki...
# ..                                                 ...
# 203  Apresentação e Introdução ao Curso,Introdução ...
# 204  Working with Multiple Worksheets & Workbooks,T...
# 205  Filtering Data Using Queries,Vector analysis,R...
# 206  Find Your Audience With Segmentation,Analytics...
# 207  Critical Core of Excel,Performing calculations...
#
#                                             instructor       certificate_type  \
# 0    Google Cloud TrainingGoogle Cloud1,482 Courses...  Shareable Certificate
# 1    Antoine GourévitchCentraleSupélec1 Course•21,6...  Shareable Certificate
# 2    Xiaobo ZhouUniversity of Colorado System4 Cour...  Shareable Certificate
# 3    Top InstructorGoogle Career CertificatesGoogle...  Shareable Certificate
# 4    Charles Russell SeveranceUniversity of Michiga...  Shareable Certificate
# ..                                                 ...                    ...
# 203  Top InstructorFabio KonUniversidade de São Pau...  Shareable Certificate
# 204  Nicky BullMacquarie University25 Courses•1,301...  Shareable Certificate
# 205  Top InstructorDon BoyesUniversity of Toronto4 ...  Shareable Certificate
# 206  Anke AudenaertMeta35 Courses•657,734 learners,...  Shareable Certificate
# 207  Nicky BullMacquarie University25 Courses•1,301...  Shareable Certificate
#
#                        association  \
# 0                     Google Cloud
# 1                  CentraleSupélec
# 2    University of Colorado System
# 3                           Google
# 4           University of Michigan
# ..                             ...
# 203                              -
# 204             IBM Skills Network
# 205                              -
# 206       University of Manchester
# 207                Duke University
#
#                                                  image  \
# 0    https://s3.amazonaws.com/coursera_assets/meta_...
# 1    https://s3.amazonaws.com/coursera_assets/meta_...
# 2    https://s3.amazonaws.com/coursera_assets/meta_...
# 3    https://s3.amazonaws.com/coursera_assets/meta_...
# 4    https://s3.amazonaws.com/coursera_assets/meta_...
# ..                                                 ...
# 203  https://s3.amazonaws.com/coursera_assets/meta_...
# 204  https://s3.amazonaws.com/coursera_assets/meta_...
# 205  https://s3.amazonaws.com/coursera_assets/meta_...
# 206  https://s3.amazonaws.com/coursera_assets/meta_...
# 207  https://s3.amazonaws.com/coursera_assets/meta_...
#
#                                                    url             timestamp
# 0    https://www.coursera.org/specializations/netwo...  2022-07-29T23:58:34Z
# 1            https://www.coursera.org/learn/2-speed-it  2022-07-29T23:58:34Z
# 2    https://www.coursera.org/learn/fundamentals-ne...  2022-07-29T23:58:54Z
# 3        https://www.coursera.org/learn/ux-design-jobs  2022-07-29T23:59:20Z
# 4    https://www.coursera.org/learn/database-applic...  2022-07-29T23:59:20Z
# ..                                                 ...                   ...
# 203  https://www.coursera.org/specializations/data-...  2022-07-30T00:45:32Z
# 204  https://www.coursera.org/professional-certific...  2022-07-30T00:45:32Z
# 205  https://www.coursera.org/specializations/jhu-d...  2022-07-30T00:45:32Z
# 206  https://www.coursera.org/learn/physical-chemistry  2022-07-30T00:45:41Z
# 207     https://www.coursera.org/learn/basic-chemistry  2022-07-30T00:45:42Z
#
# [208 rows x 18 columns]

# %% [markdown]
# ## 5.4 Handling missing value

# %%
# Handling Missing Not at Random (MNAR) value: Diasumsikan nilai kosong merupakan Beginner Level
df['level'] = df['level'].replace('-', 'Beginner Level')

# Handling Missing Not at Random (MNAR) value: Diasumsikan nilai kosong merupakan course yang free
df['price'] = df['price'].replace('-', 'free')

# Handling Missing Not at Random (MNAR) value: Diasumsikan nilai yang kosong memiliki standar rating 4
df['rating'] = df['rating'].replace('-', 4)

# Handling Missing Not at Random (MNAR) value: Diasumsikan nilai yang kosong memiliki durasi rata-rata yaitu 8 jam
df['duration'] = df['duration'].replace('-', 'Approx. 8 hours to complete')

# Handling Missing Not at Random (MNAR) value: Diasumsikan nilai yang kosong memiliki bahasa English
df['language'] = df['language'].replace('-', 'English')

# Handling Missing Not at Random (MNAR) value: Diasumsikan nilai yang kosong sebagai no prerequisites needed
df['prerequisites'] = df['prerequisites'].replace('-', 'no prerequisites needed')

# Handling Missing Not at Random (MNAR) value: Diasumsikan nilai yang kosong sebagai Non shareable certificate
df['certificate_type'] = df['certificate_type'].replace('-', 'Non Shareable Certificate')

# Handling Missing Not at Random (MNAR) value: Diasumsikan nilai yang kosong sebagai value General
df['association'] = df['association'].replace('-', 'General')

# Handling Missing Not at Random (MNAR) value: Diasumsikan nilai yang kosong sebagai No specify data
df['syllabus'] = df['syllabus'].replace('-', 'No specify data')

# %%
# Check if '-' still in df
'-' in df
# Out:
# False

# %% [markdown]
# ## 5.5 Change datatype

# %%
# Change datatype
df['rating'] = df['rating'].astype('float64')
df['timestamp'] = df['timestamp'].astype('datetime64[ns]')

# Check kembali tipe data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             208 non-null    object
#  1   category          208 non-null    object
#  2   type              208 non-null    object
#  3   level             208 non-null    object
#  4   description       208 non-null    object
#  5   price             208 non-null    object
#  6   rating            208 non-null    float64
#  7   duration          208 non-null    object
#  8   language          208 non-null    object
#  9   prerequisites     208 non-null    object
#  10  syllabus          208 non-null    object
#  11  modules           208 non-null    object
#  12  instructor        208 non-null    object
#  13  certificate_type  208 non-null    object
#  14  association       208 non-null    object
#  15  image             208 non-null    object
#  16  url               208 non-null    object
#  17  timestamp         208 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(16)
# memory usage: 29.4+ KB

# %% [markdown]
# # 6. Export Final Dataset

# %%
# Display Final Dataset
df
# Out:
#                                                  title  \
# 0            Networking in Google Cloud Specialization
# 1    Two Speed IT: How Companies Can Surf the Digit...
# 2                Fundamentals of Network Communication
# 3    Design a User Experience for Social Good & Pre...
# 4                Building Database Applications in PHP
# ..                                                 ...
# 203   Data Science: Foundations using R Specialization
# 204          IBM Data Science Professional Certificate
# 205                        Data Science Specialization
# 206                 Introduction to Physical Chemistry
# 207  Introduction to Chemistry:  Structures and Sol...
#
#                            category                       type  \
# 0                        Networking            specializations
# 1               Business Essentials                     course
# 2    Computer Security and Networks                     course
# 3                Design and Product                     course
# 4        Mobile and Web Development                     course
# ..                              ...                        ...
# 203                   Data Analysis            specializations
# 204                   Data Analysis  professional certificates
# 205                   Data Analysis            specializations
# 206                       Chemistry                     course
# 207                       Chemistry                     course
#
#                   level                                        description  \
# 0    Intermediate Level  This specialization gives participants broad s...
# 1        Beginner Level  Transform or disappear, the Darwinism of IT: I...
# 2    Intermediate Level  In this course, we trace the evolution of netw...
# 3        Beginner Level  Design a User Experience for Social Good and P...
# 4    Intermediate Level  In this course, we'll look at the object orien...
# ..                  ...                                                ...
# 203      Beginner Level  Ask the right questions, manipulate data sets,...
# 204      Beginner Level  Data science is one of the hottest professions...
# 205      Beginner Level  Ask the right questions, manipulate data sets,...
# 206      Beginner Level  Chemical reactions underpin the production of ...
# 207      Beginner Level  This is an introductory course for students wi...
#
#     price  rating                             duration language  \
# 0    free     4.8   Approximately 4 months to complete  English
# 1    free     4.3         Approx. 14 hours to complete  English
# 2    free     4.6         Approx. 15 hours to complete  English
# 3    free     4.8         Approx. 71 hours to complete  English
# 4    free     4.9         Approx. 24 hours to complete  English
# ..    ...     ...                                  ...      ...
# 203  free     4.6   Approximately 5 months to complete  English
# 204  free     4.6  Approximately 11 months to complete  English
# 205  free     4.5  Approximately 11 months to complete  English
# 206  free     4.7         Approx. 19 hours to complete  English
# 207  free     4.7         Approx. 17 hours to complete  English
#
#                prerequisites  \
# 0    no prerequisites needed
# 1    no prerequisites needed
# 2    no prerequisites needed
# 3    no prerequisites needed
# 4    no prerequisites needed
# ..                       ...
# 203  no prerequisites needed
# 204  no prerequisites needed
# 205  no prerequisites needed
# 206  no prerequisites needed
# 207  no prerequisites needed
#
#                                               syllabus  \
# 0                                      No specify data
# 1    Introduction ~.~ Start here! ~.~ IT and the CI...
# 2    Communication Networks and Services ~.~ This m...
# 3    Starting the UX design process: empathize, def...
# 4    PHP Objects ~.~ We look at the object oriented...
# ..                                                 ...
# 203                                    No specify data
# 204                                    No specify data
# 205                                    No specify data
# 206  Thermodynamics I ~.~ This module explores ther...
# 207  light ~.~ We will cover introduction to light,...
#
#                                                modules  \
# 0    Google Cloud Fundamentals: Core Infrastructure...
# 1    Introduction,IT and the CIO in the Digital Wor...
# 2    Communication Networks and Services,Layered Ar...
# 3    Design for social good and strengthen your por...
# 4    PHP Objects,Connecting PHP and MySQL,PHP Cooki...
# ..                                                 ...
# 203  Apresentação e Introdução ao Curso,Introdução ...
# 204  Working with Multiple Worksheets & Workbooks,T...
# 205  Filtering Data Using Queries,Vector analysis,R...
# 206  Find Your Audience With Segmentation,Analytics...
# 207  Critical Core of Excel,Performing calculations...
#
#                                             instructor       certificate_type  \
# 0    Google Cloud TrainingGoogle Cloud1,482 Courses...  Shareable Certificate
# 1    Antoine GourévitchCentraleSupélec1 Course•21,6...  Shareable Certificate
# 2    Xiaobo ZhouUniversity of Colorado System4 Cour...  Shareable Certificate
# 3    Top InstructorGoogle Career CertificatesGoogle...  Shareable Certificate
# 4    Charles Russell SeveranceUniversity of Michiga...  Shareable Certificate
# ..                                                 ...                    ...
# 203  Top InstructorFabio KonUniversidade de São Pau...  Shareable Certificate
# 204  Nicky BullMacquarie University25 Courses•1,301...  Shareable Certificate
# 205  Top InstructorDon BoyesUniversity of Toronto4 ...  Shareable Certificate
# 206  Anke AudenaertMeta35 Courses•657,734 learners,...  Shareable Certificate
# 207  Nicky BullMacquarie University25 Courses•1,301...  Shareable Certificate
#
#                        association  \
# 0                     Google Cloud
# 1                  CentraleSupélec
# 2    University of Colorado System
# 3                           Google
# 4           University of Michigan
# ..                             ...
# 203                        General
# 204             IBM Skills Network
# 205                        General
# 206       University of Manchester
# 207                Duke University
#
#                                                  image  \
# 0    https://s3.amazonaws.com/coursera_assets/meta_...
# 1    https://s3.amazonaws.com/coursera_assets/meta_...
# 2    https://s3.amazonaws.com/coursera_assets/meta_...
# 3    https://s3.amazonaws.com/coursera_assets/meta_...
# 4    https://s3.amazonaws.com/coursera_assets/meta_...
# ..                                                 ...
# 203  https://s3.amazonaws.com/coursera_assets/meta_...
# 204  https://s3.amazonaws.com/coursera_assets/meta_...
# 205  https://s3.amazonaws.com/coursera_assets/meta_...
# 206  https://s3.amazonaws.com/coursera_assets/meta_...
# 207  https://s3.amazonaws.com/coursera_assets/meta_...
#
#                                                    url           timestamp
# 0    https://www.coursera.org/specializations/netwo... 2022-07-29 23:58:34
# 1            https://www.coursera.org/learn/2-speed-it 2022-07-29 23:58:34
# 2    https://www.coursera.org/learn/fundamentals-ne... 2022-07-29 23:58:54
# 3        https://www.coursera.org/learn/ux-design-jobs 2022-07-29 23:59:20
# 4    https://www.coursera.org/learn/database-applic... 2022-07-29 23:59:20
# ..                                                 ...                 ...
# 203  https://www.coursera.org/specializations/data-... 2022-07-30 00:45:32
# 204  https://www.coursera.org/professional-certific... 2022-07-30 00:45:32
# 205  https://www.coursera.org/specializations/jhu-d... 2022-07-30 00:45:32
# 206  https://www.coursera.org/learn/physical-chemistry 2022-07-30 00:45:41
# 207     https://www.coursera.org/learn/basic-chemistry 2022-07-30 00:45:42
#
# [208 rows x 18 columns]

# %%
df.to_csv('coursera_dataset.csv')

# %%
data2 = pd.read_csv('coursera_dataset.csv')

# %%
data2['price'].unique()
# Out:
# array(['free', 'Enroll'], dtype=object)

# %%
data2[['title','modules']]
# Out:
#                                                  title  \
# 0            Networking in Google Cloud Specialization
# 1    Two Speed IT: How Companies Can Surf the Digit...
# 2                Fundamentals of Network Communication
# 3    Design a User Experience for Social Good & Pre...
# 4                Building Database Applications in PHP
# ..                                                 ...
# 203   Data Science: Foundations using R Specialization
# 204          IBM Data Science Professional Certificate
# 205                        Data Science Specialization
# 206                 Introduction to Physical Chemistry
# 207  Introduction to Chemistry:  Structures and Sol...
#
#                                                modules
# 0    Google Cloud Fundamentals: Core Infrastructure...
# 1    Introduction,IT and the CIO in the Digital Wor...
# 2    Communication Networks and Services,Layered Ar...
# 3    Design for social good and strengthen your por...
# 4    PHP Objects,Connecting PHP and MySQL,PHP Cooki...
# ..                                                 ...
# 203  Apresentação e Introdução ao Curso,Introdução ...
# 204  Working with Multiple Worksheets & Workbooks,T...
# 205  Filtering Data Using Queries,Vector analysis,R...
# 206  Find Your Audience With Segmentation,Analytics...
# 207  Critical Core of Excel,Performing calculations...
#
# [208 rows x 2 columns]

# %%
data2['modules'][205]
# Out:
# "Filtering Data Using Queries,Vector analysis,Remote sensing as a GIS data source,Raster analysis,Project: Spatial Analysis,Instructor,Offered by,Recommended if you're interested in Environmental Science and Sustainability,More questions"
